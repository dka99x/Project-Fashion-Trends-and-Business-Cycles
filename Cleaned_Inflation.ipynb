# %%
import numpy as np
import sklearn
from sklearn.datasets import load_diabetes
import pandas as pd
import matplotlib.pyplot as plt

# %%
nf = pd.read_csv('Inflation1.csv')

# %%
import seaborn as sns
sns.boxplot(nf.iloc[:,[8]])
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(nf['Year'], nf.iloc[:,[28]])
ax.set_xlabel('(Year)')
ax.set_ylabel('(Inflation Rate)')
plt.show()

# %%
nf.iloc[:,[23]] = np.where(nf.iloc[:,[23]] > 50,

   mean_nf,

       nf.iloc[:,[23]]

   )

# %%
mean_nf = nf.iloc[:,[25]].mean()

# %%
nf.iloc[:,[25]] = np.where(nf.iloc[:,[25]] == 0,

   mean_nf,

       nf.iloc[:,[25]]

   )

nf
# Out:
#     Year  Austria    Belgium   Bulgaria    Croatia  Cyprus  Czech Republic  \
# 0   1980      6.3   6.700000  44.637778  37.935556    13.5        2.502222
# 1   1981      6.8   7.600000  44.637778  37.935556    10.7        2.502222
# 2   1982      5.4   8.700000   2.800000  37.935556     6.4        2.502222
# 3   1983      3.3   7.700000   2.800000  37.935556     5.0        2.502222
# 4   1984      5.7   6.300000   2.800000  37.935556     6.0        2.502222
# 5   1985      3.2   4.900000   2.800000  37.935556     5.0        2.502222
# 6   1986      1.7   1.300000   2.700000  37.935556     1.2        2.502222
# 7   1987      1.4   1.600000   2.700000  37.935556     2.7        2.502222
# 8   1988      1.9   1.200000   2.500000  37.935556     3.4        2.502222
# 9   1989      2.2   3.100000   6.400000  37.935556     3.8        2.502222
# 10  1990      2.8   3.500000  23.900000  37.935556     4.5        2.502222
# ...

# %%
nf.iloc[:,[16]]
# Out:
#        Latvia
# 0    6.882222
# 1    6.882222
# 2    6.882222
# 3    6.882222
# 4    6.882222
# 5    6.882222
# 6    6.882222
# 7    6.882222
# 8    6.882222
# 9    6.882222
# 10   6.882222
# 11   6.882222
# 12   6.882222
# 13   6.882222
# 14  35.900000
# 15  25.000000
# 16  17.600000
# 17   8.100000
# 18   4.300000
# 19   2.100000
# 20   2.600000
# 21   2.500000
# 22   2.000000
# 23   2.900000
# 24   6.200000
# 25   6.900000
# 26   6.600000
# 27  10.100000
# 28  15.300000
# 29   3.300000
# 30  -1.200000
# 31   4.200000
# 32   2.300000
# 33   6.882222
# 34   0.700000
# 35   0.200000
# 36   0.100000
# 37   2.900000
# 38   2.600000
# 39   2.700000
# 40   0.100000
# 41   3.200000
# 42  17.200000
# 43   9.900000
# 44   4.200000

# %%
nf.to_csv('Inflation1.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Plot the Inflation Rate
nf.plot(x='Year', y=['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 
    'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 
    'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy', 
    'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Netherlands', 
    'Poland', 'Portugal', 'Romania', 'Slovak Republic', 'Slovenia', 
    'Spain', 'Sweden', 'United Kingdom'], figsize=(10,5))

# Set the x-axis label
plt.xlabel('Year')

# Set the y-axis label
plt.ylabel('Inflation Rate')

# Set the title of the plot
plt.title('Inflation Rate of EU & UK Countries Over Time')

# Display the plot
plt.show()
